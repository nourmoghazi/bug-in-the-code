# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedmoustafa/bug-in-the-code/blob/main/bug-in-the-code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bug in the Code

# %%
print ('Python is the world's most popular programming language!')
